# %% [markdown]
# <a href="https://colab.research.google.com/github/pyijiezhang/cold-posteriors-and-pacbayes/blob/main/results_vi_nn_classification_andres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pickle

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import files

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['figure.figsize'] = (16, 9)
fontsize = 35
matplotlib.rcParams.update({'font.size': fontsize})
from matplotlib.pyplot import figure

# %%
def get_metrics(results):

    metrics_dict = {}

    for seed in results.keys():

        result_seed = results[seed]
        cpe_weights = list(result_seed.keys())
        # cpe_weights.remove("setting")

        _, n_post_samples = result_seed[cpe_weights[0]][0].shape

        metrics_dict[seed] = {}

        metrics_dict[seed]["nll_gibbs_train"] = []
        metrics_dict[seed]["nll_gibbs_test"] = []
        metrics_dict[seed]["nll_bayes_train"] = []
        metrics_dict[seed]["nll_bayes_test"] = []

        metrics_dict[seed]["err_gibbs_train"] = []
        metrics_dict[seed]["err_gibbs_test"] = []
        metrics_dict[seed]["err_bayes_train"] = []
        metrics_dict[seed]["err_bayes_test"] = []

        # metrics_dict[seed]["grad_nll_gibbs"]=[]

        for cpe_weight in cpe_weights:

            log_p_train = torch.tensor(result_seed[cpe_weight][0])
            log_p_test = torch.tensor(result_seed[cpe_weight][1])

            metrics_dict[seed]["nll_gibbs_train"].append(-log_p_train.mean().item())
            metrics_dict[seed]["nll_gibbs_test"].append(-log_p_test.mean().item())

            bayes_loss_train = (
                (
                    torch.log(torch.tensor(n_post_samples))
                    - torch.logsumexp(log_p_train, 1)
                )
                .mean()
                .item()
            )
            metrics_dict[seed]["nll_bayes_train"].append(bayes_loss_train)
            bayes_loss_test = (
                (
                    torch.log(torch.tensor(n_post_samples))
                    - torch.logsumexp(log_p_test, 1)
                )
                .mean()
                .item()
            )
            metrics_dict[seed]["nll_bayes_test"].append(bayes_loss_test)

            # grad_expected_gibbs = (
            #         -n_train
            #         * (
            #             (log_p_train.mean(0) * log_p_test.mean(0)).mean()
            #             - log_p_test.mean() * log_p_train.mean()
            #         ).item()
            #     )
            # metrics_dict[seed]["grad_nll_gibbs"].append(grad_expected_gibbs)

            metrics_dict[seed]["err_gibbs_train"].append(
                1 - np.array(result_seed[cpe_weight][2])[:, 1].mean()
            )
            metrics_dict[seed]["err_gibbs_test"].append(
                1 - np.array(result_seed[cpe_weight][3])[:, 1].mean()
            )
            metrics_dict[seed]["err_bayes_train"].append(
                1 - np.array(result_seed[cpe_weight][4])[:, 1].mean()
            )
            metrics_dict[seed]["err_bayes_test"].append(
                1 - np.array(result_seed[cpe_weight][5])[:, 1].mean()
            )

    return metrics_dict

# %% [markdown]
# # in-between seeds

# %%
# dir_prefix = f"./between seeds/{setting_i}/"
# if not os.path.exists(dir_prefix):
#     os.makedirs(dir_prefix)

# %%
# name_metrics=list(metrics[seeds[0]].keys())
# for name_metric in name_metrics:
#     save_name=f"{name_metric}"
#     plt.figure()
#     plt.title(save_name)
#     for seed in seeds:
#         plt.plot(np.arange(0,len(cpe_weights),1),metrics[seed][name_metric], marker="o", label=f"{seed}")

#     plt.xticks(np.arange(0,len(cpe_weights),1), np.log10(cpe_weights))
#     plt.legend()
#     plt.xlabel("lambda, log scale")
#     plt.ylabel(name_metric)
#     plt.ylim(0,0.1)
#     # plt.savefig(f"./{dir_prefix}/{save_name}.png", dpi=300)
#     plt.show()

# %% [markdown]
# # main plots
# ## prior

# %%
dir='./cold-posteriors-and-pacbayes/results/bnn_classification_mfvi/results_big_lenet_batchsize_100_epoch_100'

# %%
all_metrics_priors = {}
for prior_scale in [0.01, 0.1, 1.0]:
    setting_i = f"{dir}/prior_scale_{prior_scale}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_False"

    with open(f"{setting_i}.pickle", "rb") as handle:
        results = pickle.load(handle)
    metrics = get_metrics(results)
    seeds = list(results.keys())
    cpe_weights = list(results[seeds[0]].keys())
    # cpe_weights.remove("setting")

    all_metrics_priors[prior_scale] = metrics

    dir_prefix = f"./main/{setting_i}/"
    if not os.path.exists(dir_prefix):
        os.makedirs(dir_prefix)

    name_metrics = ["nll", "err"]
    for metric in name_metrics:
        for seed in seeds:
            save_name = f"main_{metric}_{seed}"
            plt.title(f"{seed}")
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_gibbs_train"],
                marker="o",
                label=f"{metric}_gibbs_train",
            )
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_bayes_test"],
                marker="o",
                label=f"{metric}_bayes_test",
            )
            # plt.xticks(np.arange(0,len(cpe_weights),1), np.log10(cpe_weights))
            plt.xticks(np.arange(0, len(cpe_weights), 1), cpe_weights)
            plt.xlabel("lambda")
            plt.ylabel(f"{metric}")
            # plt.ylim(0,0.5)
            plt.legend()
            plt.savefig(f"{dir_prefix}/{save_name}.png", dpi=300)
            plt.show()

# %%
name_metric = "err_bayes_test"
name_seed = 15
df = pd.DataFrame()
for prior_scale in [0.01, 0.1, 1.0]:
    this_df = pd.DataFrame.from_dict(all_metrics_priors[prior_scale][name_seed])[name_metric]
    this_df.rename(prior_scale, inplace=True)
    df = pd.concat([df, this_df], axis=1)
df.index = list(np.linspace(0.5, 3.5, 7))

# %%
df
# Out:
#        0.01    0.10    1.00
# 0.5  0.8865  0.0146  0.0153
# 1.0  0.1200  0.0114  0.0118
# 1.5  0.0703  0.0089  0.0097
# 2.0  0.0615  0.0094  0.0079
# 2.5  0.0544  0.0096  0.0092
# 3.0  0.0480  0.0084  0.0075
# 3.5  0.0439  0.0082  0.0088

# %%
all_metrics_priors_aug = {}
for prior_scale in [0.01, 0.1, 1.0]:
    setting_i = f"{dir}/prior_scale_{prior_scale}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_True"

    with open(f"{setting_i}.pickle", "rb") as handle:
        results = pickle.load(handle)
    metrics = get_metrics(results)
    seeds = list(results.keys())
    cpe_weights = list(results[seeds[0]].keys())
    # cpe_weights.remove("setting")

    all_metrics_priors_aug[prior_scale] = metrics

    dir_prefix = f"./main/{setting_i}/"
    if not os.path.exists(dir_prefix):
        os.makedirs(dir_prefix)

    name_metrics = ["nll", "err"]
    for metric in name_metrics:
        for seed in seeds:
            save_name = f"main_{metric}_{seed}"
            plt.title(f"{seed}")
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_gibbs_train"],
                marker="o",
                label=f"{metric}_gibbs_train",
            )
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_bayes_test"],
                marker="o",
                label=f"{metric}_bayes_test",
            )
            # plt.xticks(np.arange(0,len(cpe_weights),1), np.log10(cpe_weights))
            plt.xticks(np.arange(0, len(cpe_weights), 1), cpe_weights)
            plt.xlabel("lambda")
            plt.ylabel(f"{metric}")
            # plt.ylim(0,0.5)
            plt.legend()
            plt.savefig(f"{dir_prefix}/{save_name}.png", dpi=300)
            plt.show()

# %% [markdown]
# ## smooth softmax

# %%
all_metrics_softmax = {}
for gamma in [1.0, 5.0, 10.0]:
    setting_i = f"{dir}/prior_scale_0.01_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_False"

    with open(f"{setting_i}.pickle", "rb") as handle:
        results = pickle.load(handle)
    metrics = get_metrics(results)
    seeds = list(results.keys())
    cpe_weights = list(results[seeds[0]].keys())
    # cpe_weights.remove("setting")

    all_metrics_softmax[gamma] = metrics

    dir_prefix = f"./main/{setting_i}/"
    if not os.path.exists(dir_prefix):
        os.makedirs(dir_prefix)

    name_metrics = ["nll", "err"]
    for metric in name_metrics:
        for seed in seeds:
            save_name = f"main_{metric}_{seed}"
            plt.title(f"{seed}")
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_gibbs_train"],
                marker="o",
                label=f"{metric}_gibbs_train",
            )
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_bayes_test"],
                marker="o",
                label=f"{metric}_bayes_test",
            )
            # plt.xticks(np.arange(0,len(cpe_weights),1), np.log10(cpe_weights))
            plt.xticks(np.arange(0, len(cpe_weights), 1), cpe_weights)
            plt.xlabel("lambda")
            plt.ylabel(f"{metric}")
            # plt.ylim(0,0.5)
            plt.legend()
            plt.savefig(f"{dir_prefix}/{save_name}.png", dpi=300)
            plt.show()

# %%
all_metrics_softmax_prior = {}
for gamma in [1.0, 5.0, 10.0]:
    setting_i = f"{dir}/prior_scale_0.01_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_False"

    with open(f"{setting_i}.pickle", "rb") as handle:
        results = pickle.load(handle)
    metrics = get_metrics(results)
    seeds = list(results.keys())
    cpe_weights = list(results[seeds[0]].keys())
    # cpe_weights.remove("setting")

    all_metrics_softmax_prior[gamma] = metrics

    dir_prefix = f"./main/{setting_i}/"
    if not os.path.exists(dir_prefix):
        os.makedirs(dir_prefix)

    name_metrics = ["nll", "err"]
    for metric in name_metrics:
        for seed in seeds:
            save_name = f"main_{metric}_{seed}"
            plt.title(f"{seed}")
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_gibbs_train"],
                marker="o",
                label=f"{metric}_gibbs_train",
            )
            plt.plot(
                np.arange(0, len(cpe_weights), 1),
                metrics[seed][f"{metric}_bayes_test"],
                marker="o",
                label=f"{metric}_bayes_test",
            )
            # plt.xticks(np.arange(0,len(cpe_weights),1), np.log10(cpe_weights))
            plt.xticks(np.arange(0, len(cpe_weights), 1), cpe_weights)
            plt.xlabel("lambda")
            plt.ylabel(f"{metric}")
            # plt.ylim(0,0.5)
            plt.legend()
            plt.savefig(f"{dir_prefix}/{save_name}.png", dpi=300)
            plt.show()

# %%
name_metric = "nll_bayes_test"
name_seed = 15
df = pd.DataFrame()
for gamma in [1.0, 5.0, 10.0]:
    this_df = pd.DataFrame.from_dict(all_metrics_softmax[gamma][name_seed])[name_metric]
    this_df.rename(gamma, inplace=True)
    df = pd.concat([df, this_df], axis=1)
df.index = list(np.linspace(0.5, 3.5, 7))

# %%
df
# Out:
#          1.0       5.0       10.0
# 0.5  2.301839  2.301401  2.302092
# 1.0  0.472233  0.258012  0.222602
# 1.5  0.298221  0.199211  0.169835
# 2.0  0.247979  0.167253  0.143146
# 2.5  0.212168  0.138425  0.119802
# 3.0  0.184917  0.124440  0.112811
# 3.5  0.165641  0.111231  0.101684

# %% [markdown]
# # Joint Plots - Softmax

# %%
import matplotlib.pyplot as plt
import numpy as np

seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
test_loss_g = "nll_gibbs_test"

y_lim=[0,0.6]
x_lim=[0.25,3.75]
# generate some random data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# create a 2x2 grid of subplots with larger subplots and spacing
fig, axs = plt.subplots(2, 2, figsize=(8, 8))

prior=0.01

# plot the data on each subplot and set the limits
axs[0, 0].plot(cpe_weights, all_metrics_priors[prior][seed][train_loss], marker="o", label=train_loss)
axs[0, 0].plot(cpe_weights, all_metrics_priors[prior][seed][test_loss], marker="o", label=test_loss)
axs[0, 0].plot(cpe_weights, all_metrics_priors[prior][seed][test_loss_g], marker="o", label=test_loss_g)
axs[0, 0].set_xlim(x_lim)
axs[0, 0].set_ylim(y_lim)
axs[0, 0].set_title("Prior 0.01, Smooth=1")
axs[0, 0].legend()


prior=1.0
axs[0, 1].plot(cpe_weights, all_metrics_priors[prior][seed][train_loss], marker="o", label=train_loss)
axs[0, 1].plot(cpe_weights, all_metrics_priors[prior][seed][test_loss], marker="o", label=test_loss)
axs[0, 1].plot(cpe_weights, all_metrics_priors[prior][seed][test_loss_g], marker="o", label=test_loss_g)
axs[0, 1].set_xlim(x_lim)
axs[0, 1].set_ylim(y_lim)
axs[0, 1].set_title("Prior 1.0, Smooth=1")
axs[0, 1].legend()



gamma=10.0
axs[1, 0].plot(cpe_weights, all_metrics_softmax[gamma][seed][train_loss], marker="o", label=train_loss)
axs[1, 0].plot(cpe_weights, all_metrics_softmax[gamma][seed][test_loss], marker="o", label=test_loss)
axs[1, 0].plot(cpe_weights, all_metrics_softmax[gamma][seed][test_loss_g], marker="o", label=test_loss_g)
axs[1, 0].set_xlim(x_lim)
axs[1, 0].set_ylim(y_lim)
axs[1, 0].set_title("Prior 0.01, Smooth=10")
axs[1, 0].legend()


gamma=10.0
axs[1, 1].plot(cpe_weights, all_metrics_softmax_prior[gamma][seed][train_loss], marker="o", label=train_loss)
axs[1, 1].plot(cpe_weights, all_metrics_softmax_prior[gamma][seed][test_loss], marker="o", label=test_loss)
axs[1, 1].plot(cpe_weights, all_metrics_softmax_prior[gamma][seed][test_loss_g], marker="o", label=test_loss_g)
axs[1, 1].set_xlim(x_lim)
axs[1, 1].set_ylim(y_lim)
axs[1, 1].set_title("Prior 1.0, Smooth=10")
axs[1, 1].legend()



# adjust the spacing between subplots
fig.tight_layout()

plt.savefig("cold-posterior-images/biglenet-jointplots-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 

# show the plot
plt.show()
# Out:
# <ipython-input-15-9451619a1fb0>:66: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
test_loss_g = "nll_gibbs_test"

train_loss_label = "$\hat{G}(p^\lambda,D)$"
test_loss_label = "$B(p^\lambda)$"


line_width=7
marker_size=20


y_lim=[0,0.6]
x_lim=[0.25,3.75]

priors = [0.01, 1.0]

all_metrics_priors[prior][seed][train_loss]

gamma=1
for prior in priors:
  plt.plot(cpe_weights, all_metrics_priors[prior][seed][train_loss], marker="o", label=train_loss_label,linewidth=line_width,markersize=marker_size)
  plt.plot(cpe_weights, all_metrics_priors[prior][seed][test_loss], marker="o", label=test_loss_label,linewidth=line_width,markersize=marker_size)
  plt.xlim(x_lim[0], x_lim[1])
  plt.ylim(y_lim[0], y_lim[1])
  plt.title(f"CNN  [$\sigma=${prior},$\gamma$={gamma}]")
  plt.xlabel("$\lambda$")
  plt.ylabel("nll")
  plt.legend()
  plt.grid()  
  plt.savefig(f"cold-posterior-images/biglenet-prior-{prior}-gamma-{gamma}-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 
  plt.show()


priors = [0.01, 1.0]

gamma=10
for prior in priors:
  plt.plot(cpe_weights, all_metrics_softmax_prior[gamma][seed][train_loss], marker="o", label=train_loss_label,linewidth=line_width,markersize=marker_size)
  plt.plot(cpe_weights, all_metrics_softmax_prior[gamma][seed][test_loss], marker="o", label=test_loss_label,linewidth=line_width,markersize=marker_size)
  plt.xlim(x_lim[0], x_lim[1])
  plt.ylim(y_lim[0], y_lim[1])
  plt.title(f"CNN  [$\sigma=${prior},$\gamma$={gamma}]")
  plt.xlabel("$\lambda$")
  plt.ylabel("nll")
  plt.legend()
  plt.grid()
  plt.savefig(f"cold-posterior-images/biglenet-prior-{prior}-gamma-{gamma}-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 
  plt.show()

# %% [markdown]
# # Joint Plots Data Augmentation

# %%
import matplotlib.pyplot as plt
import numpy as np

prior=1.0

seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
y_lim=[0,0.2]
x_lim=[0.25,3.75]
# generate some random data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# create a 2x2 grid of subplots with larger subplots and spacing
fig, axs = plt.subplots(1, 4, figsize=(16, 4))


# plot the data on each subplot and set the limits
axs[0].plot(cpe_weights, all_metrics_priors[prior][seed][train_loss], marker="o", label=train_loss)
axs[0].plot(cpe_weights, all_metrics_priors[prior][seed][test_loss], marker="o", label=test_loss)
axs[0].set_xlim(x_lim)
axs[0].set_ylim(y_lim)
axs[0].set_title(f"Prior {prior}, w/o DA")
axs[0].legend()


axs[1].plot(cpe_weights, all_metrics_priors_aug[prior][seed][train_loss], marker="o", label=train_loss)
axs[1].plot(cpe_weights, all_metrics_priors_aug[prior][seed][test_loss], marker="o", label=test_loss)
axs[1].set_xlim(x_lim)
axs[1].set_ylim(y_lim)
axs[1].set_title(f"Prior {prior}, w DA")
axs[1].legend()


setting_i = f"{dir}/prior_scale_{prior_scale}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_Replacement"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)


axs[2].plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss)
axs[2].plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss)
#axs[2].set_xlim(x_lim)
#axs[2].set_ylim(y_lim)
axs[2].set_title(f"Prior {prior}, w Replacement")
axs[2].legend()


setting_i = f"{dir}/prior_scale_{prior_scale}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_Noise"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)


axs[3].plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss)
axs[3].plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss)
#axs[3].set_xlim(x_lim)
#axs[3].set_ylim(y_lim)
axs[3].set_title(f"Prior {prior}, w Noise")
axs[3].legend()


# adjust the spacing between subplots
fig.tight_layout()

plt.savefig("cold-posterior-images/biglenet-jointplots-data-augmentation-gibbs.pdf", format = "pdf",bbox_inches='tight') 

# show the plot
plt.show()
# Out:
# <ipython-input-23-62e1314137f0>:70: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
test_loss_g = "nll_gibbs_test"

train_loss_label = "$\hat{G}(p^\lambda,D)$"
test_loss_label = "$B(p^\lambda)$"
test_loss_g_label = "$G(p^\lambda)$"

line_width=7
marker_size=20
y_lim=[0,0.2]
x_lim=[0.25,3.75]

#No-DA
prior=1.0
plt.plot(cpe_weights, all_metrics_priors[prior][seed][train_loss], marker="o", label=train_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, all_metrics_priors[prior][seed][test_loss], marker="o", label=test_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, all_metrics_priors[prior][seed][test_loss_g], marker="o", label=test_loss_g_label,linewidth=line_width,markersize=marker_size)

plt.xlim(x_lim[0], x_lim[1])
plt.ylim(y_lim[0], y_lim[1])
#plt.title(f"CNN  [$\sigma=${prior}, W]")
plt.xlabel("$\lambda$")
plt.ylabel("nll")
plt.legend()
plt.grid()  
plt.savefig(f"cold-posterior-images/biglenet-prior-{prior}-No-DA-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 
plt.show()

#DA
plt.plot(cpe_weights, all_metrics_priors_aug[prior][seed][train_loss], marker="o", label=train_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, all_metrics_priors_aug[prior][seed][test_loss], marker="o", label=test_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, all_metrics_priors_aug[prior][seed][test_loss_g], marker="o", label=test_loss_g_label,linewidth=line_width,markersize=marker_size)
plt.xlim(x_lim[0], x_lim[1])
plt.ylim(y_lim[0], y_lim[1])
#plt.title(f"CNN  [$\sigma=${prior}, W]")
plt.xlabel("$\lambda$")
plt.ylabel("nll")
plt.legend()
plt.grid()  
plt.savefig(f"cold-posterior-images/biglenet-prior-{prior}-DA-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 
plt.show()


#Shuffled
setting_i = f"{dir}/prior_scale_{prior_scale}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_Noise"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)


plt.plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss_label,linewidth=line_width,markersize=marker_size)
plt.plot(cpe_weights, metrics[seed][test_loss_g], marker="o", label=test_loss_g_label,linewidth=line_width,markersize=marker_size)
#plt.xlim(x_lim[0], x_lim[1])
#plt.ylim(y_lim[0], y_lim[1])
#plt.title(f"CNN  [$\sigma=${prior}, W]")
plt.xlabel("$\lambda$")
plt.ylabel("nll")
plt.legend()
plt.grid()  
plt.savefig(f"cold-posterior-images/biglenet-prior-{prior}-Shuffle-DA-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 
plt.show()

# %% [markdown]
# # Exploring Data Augmentation

# %%
seed=15
prior=1.0
lamb=1.0
da=True
setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_1.0_data_augmentation_{da}"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)


print(results[seed][lamb][0].shape)

log_p_train = np.sum(results[seed][lamb][0],axis=0)
log_p_test = results[seed][lamb][1]
prob_test = np.exp(log_p_test)

log_p_train = np.tile(log_p_train, (prob_test.shape[0], 1))
cov = np.mean(log_p_train*prob_test,axis=1) - np.mean(log_p_train,axis=1)*np.mean(prob_test,axis=1)
prob_mean = np.mean(prob_test,axis=1)
cov_mean = np.mean(cov/prob_mean)

#plt.boxplot(results[seed][lamb][0]);
np.min(cov)
# Out:
# (60000, 10)
# -173.43262

# %% [markdown]
# ## Gradient Bayes Loss

# %%
def gradientBayesLoss(seed, prior, lamb, gamma, da):

  setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_{da}"

  with open(f"{setting_i}.pickle", "rb") as handle:
    results = pickle.load(handle)


  log_p_train = np.sum(results[seed][lamb][0],axis=0)
  log_p_test = results[seed][lamb][1]
  prob_test = np.exp(log_p_test)

  log_p_train = np.tile(log_p_train, (prob_test.shape[0], 1))

  cov = np.mean(log_p_train*prob_test,axis=1) - np.mean(log_p_train,axis=1)*np.mean(prob_test,axis=1)
  prob_mean = np.mean(prob_test,axis=1)
  cov_mean = np.mean(cov/prob_mean)
  return -cov_mean, -cov, prob_mean

# %%
seed=15
lambdas = [1.0, 1.5, 2.5, 3.0]
da=False
vals = [gradientBayesLoss(seed, 0.01, lamb, 1.0, da)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Prior-0.01")
vals = [gradientBayesLoss(seed, 1.0, lamb, 1.0, da)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Prior-1.0")
plt.ylim(-1,1)
plt.title("Gradient")
plt.legend()

# %%
seed=15
da=False
vals = [gradientBayesLoss(seed, 0.01, lamb, 1.0, da)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Gamma-1.0")
vals = [gradientBayesLoss(seed, 0.01, lamb, 10.0, da)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Gamma-10.0")
plt.ylim(-1,1)
plt.title("Gradient")
plt.legend()

# %%
seed=15
prior=1.0
lambdas = [1.0, 1.5, 2.5, 3.0]
vals = [gradientBayesLoss(seed, 1.0, lamb, 1.0, False)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="No DA")
vals = [gradientBayesLoss(seed, 1.0, lamb, 1.0, True)[0] for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="DA")
plt.ylim(-2,2)
plt.title("Gradient")
plt.legend()

# %% [markdown]
# ## Gradient Gibbs Loss

# %%
def gradientGibbsLoss(seed, prior=1.0, lamb=1.0, gamma=1.0, da=False):

  setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_{da}"

  with open(f"{setting_i}.pickle", "rb") as handle:
    results = pickle.load(handle)


  log_p_train = np.sum(results[seed][lamb][0],axis=0)
  log_p_test = -np.mean(results[seed][lamb][1],axis=0)

  cov = np.mean(log_p_train*log_p_test,axis=0) - np.mean(log_p_train,axis=0)*np.mean(log_p_test,axis=0)
  return np.cov(log_p_train,log_p_test)[0, 1]

# %%
seed=15
lambdas = [1.0, 1.5, 2.5, 3.0]
vals = [gradientGibbsLoss(seed, prior=0.01, lamb=lamb, gamma=1.0, da=False) for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Prior-0.01")
vals = [gradientGibbsLoss(seed, prior=1.0, lamb=lamb, gamma=1.0, da=False) for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="Prior-1.0")
plt.title("Gradient Gibbs Loss")
plt.legend()

# %%
seed=15
prior=1.0
da=True
lambdas = [1.0, 1.5, 2.5, 3.0]
vals = [gradientGibbsLoss(seed, prior, lamb, da) for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="DA")
da=False
vals = [gradientGibbsLoss(seed, prior, lamb, da) for lamb in lambdas]
plt.plot(lambdas,vals, marker="o", label="No DA")
plt.title("Gradient Gibbs Loss")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-6eb9cd61cb69> in <module>
#       3 da=True
#       4 lambdas = [1.0, 1.5, 2.5, 3.0]
# ----> 5 vals = [gradientGibbsLoss(seed, prior, lamb, da) for lamb in lambdas]
#       6 plt.plot(lambdas,vals, marker="o", label="DA")
#       7 da=False
#
# <ipython-input-23-6eb9cd61cb69> in <listcomp>(.0)
#       3 da=True
#       4 lambdas = [1.0, 1.5, 2.5, 3.0]
# ----> 5 vals = [gradientGibbsLoss(seed, prior, lamb, da) for lamb in lambdas]
#       6 plt.plot(lambdas,vals, marker="o", label="DA")
#       7 da=False
#
# <ipython-input-21-0d1e27bc6937> in gradientGibbsLoss(seed, prior, lamb, gamma, da)
#       3   setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_{da}"
#       4
# ----> 5   with open(f"{setting_i}.pickle", "rb") as handle:
#       6     results = pickle.load(handle)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: './cold-posteriors-and-pacbayes/results/bnn_classification_mfvi/results_big_lenet_batchsize_100_epoch_100/prior_scale_1.0_label_noise_0.0_smooth_softmax_True_data_augmentation_False.pickle'

# %% [markdown]
# ## Scatter Plots

# %%
def scatterGibbs(seed, prior=1.0, lamb=1.0, gamma=1.0, da=False):

  setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_{da}"

  with open(f"{setting_i}.pickle", "rb") as handle:
    results = pickle.load(handle)


  log_p_train = -np.sum(results[seed][lamb][0],axis=0)
  log_p_test = -np.mean(results[seed][lamb][1],axis=0)

  plt.scatter(log_p_train,log_p_test)

  return np.cov(log_p_train,log_p_test)[0, 1], np.corrcoef(log_p_train,log_p_test)[0, 1]

# %%
scatterGibbs(seed, prior=1.0, lamb=1.0, gamma=10.0, da=False)

# %% [markdown]
# # MLP Plots

# %%
dir='./cold-posteriors-and-pacbayes/results/bnn_classification_mfvi/results_MLP_batchsize_100_epoch_10000_lr_0_0001'

# %%
import matplotlib.pyplot as plt
import numpy as np

seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
test_loss_g = "nll_gibbs_test"

y_lim=[0,6.0]
x_lim=[0.25,3.75]
# generate some random data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# create a 2x2 grid of subplots with larger subplots and spacing
fig, axs = plt.subplots(1, 2, figsize=(8, 4))

prior=1.0
gamma=1.0

setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_None_MLP_100"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)
cpe_weights = list(results[seeds[0]].keys())

# plot the data on each subplot and set the limits
axs[0].plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss)
axs[0].plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss)
#axs[0, 0].plot(cpe_weights, metrics[seed][test_loss_g], marker="o", label=test_loss_g)
#axs[0].set_xlim(x_lim)
#axs[0].set_ylim(y_lim)
axs[0].set_title(f"Prior {prior}, Smooth={gamma}")
axs[0].legend()


prior=1.0
gamma=10.0

setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_None_MLP_100"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)


axs[1].plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss)
axs[1].plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss)
#axs[1].plot(cpe_weights, metrics[seed][test_loss_g], marker="o", label=test_loss_g)
axs[1].set_xlim(x_lim)
axs[1].set_ylim(y_lim)
axs[1].set_title(f"Prior {prior}, Smooth={gamma}")
axs[1].legend()


# adjust the spacing between subplots
fig.tight_layout()

plt.savefig("cold-posterior-images/mlp-jointplots-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 

# show the plot
plt.show()

# %%
dir='./cold-posteriors-and-pacbayes/results/bnn_classification_mfvi/results_MLP_batchsize_100_epoch_10000_lr_0_0001'

seed=15
train_loss = "nll_gibbs_train"
test_loss = "nll_bayes_test"
test_loss_g = "nll_gibbs_test"

y_lim=[0,6.0]
x_lim=[0.25,3.75]

prior=1.0
gamma=10.0

setting_i = f"{dir}/prior_scale_{prior}_label_noise_0.0_smooth_softmax_{gamma}_data_augmentation_None_MLP_100"

with open(f"{setting_i}.pickle", "rb") as handle:
  results = pickle.load(handle)
metrics = get_metrics(results)
cpe_weights = list(results[seeds[0]].keys())

# plot the data on each subplot and set the limits
plt.plot(cpe_weights, metrics[seed][train_loss], marker="o", label=train_loss,linewidth=10)
plt.plot(cpe_weights, metrics[seed][test_loss], marker="o", label=test_loss,linewidth=10)

plt.title(f"MLP  [$\sigma=${prior},$\gamma$={gamma}]")
plt.xlabel("$\lambda$")
plt.ylabel("nll")
plt.legend()
plt.grid()
plt.savefig(f"cold-posterior-images/mlp-prior-{prior}-gamma-{gamma}-model-misspecification.pdf", format = "pdf",bbox_inches='tight') 

# show the plot
plt.show()

# %% [markdown]
# # Download results

# %%
# !zip results.zip *.pickle
# Out:
#   adding: prior_scale_0.01_label_noise_0.0_smooth_softmax_10.0_data_augmentation_None_MLP_10000.pickle (deflated 14%)
#   adding: prior_scale_0.01_label_noise_0.0_smooth_softmax_10.0_data_augmentation_None_MLP_100.pickle (deflated 14%)
#   adding: prior_scale_0.01_label_noise_0.0_smooth_softmax_1.0_data_augmentation_None_MLP_10000.pickle (deflated 23%)
#   adding: prior_scale_0.01_label_noise_0.0_smooth_softmax_1.0_data_augmentation_None_MLP_100.pickle (deflated 23%)
#   adding: prior_scale_1.0_label_noise_0.0_smooth_softmax_10.0_data_augmentation_None_MLP_10000.pickle (deflated 77%)
#   adding: prior_scale_1.0_label_noise_0.0_smooth_softmax_10.0_data_augmentation_None_MLP_100.pickle (deflated 57%)
#   adding: prior_scale_1.0_label_noise_0.0_smooth_softmax_1.0_data_augmentation_None_MLP_10000.pickle (deflated 7%)
#   adding: prior_scale_1.0_label_noise_0.0_smooth_softmax_1.0_data_augmentation_None_MLP_100.pickle (deflated 15%)

# %%
from google.colab import files
files.download('results.zip')

# %%
# !git clone https://github.com/pyijiezhang/cold-posteriors-and-pacbayes

# %%
files.download("cold-posterior-images/biglenet-jointplots-model-misspecification-gibbs.pdf")

# %%
# !zip images.zip cold-posterior-images/*.pdf
# Out:
# updating: cold-posterior-images/biglenet-jointplots-data-augmentation-gibbs.pdf (deflated 19%)
# updating: cold-posterior-images/biglenet-jointplots-data-augmentation.pdf (deflated 33%)
# updating: cold-posterior-images/biglenet-jointplots-model-misspecification-gibbs.pdf (deflated 36%)
# updating: cold-posterior-images/biglenet-jointplots-model-misspecification.pdf (deflated 24%)
# updating: cold-posterior-images/biglenet-prior-0.01-gamma-10-model-misspecification.pdf (deflated 16%)
# updating: cold-posterior-images/biglenet-prior-0.01-gamma-1-model-misspecification.pdf (deflated 16%)
# updating: cold-posterior-images/biglenet-prior-1.0-gamma-10-model-misspecification.pdf (deflated 16%)
# updating: cold-posterior-images/biglenet-prior-1.0-gamma-1-model-misspecification.pdf (deflated 16%)
# updating: cold-posterior-images/mlp-jointplots-model-misspecification.pdf (deflated 16%)
# updating: cold-posterior-images/mlp-prior-1.0-gamma-10.0-model-misspecification.pdf (deflated 16%)
#   adding: cold-posterior-images/biglenet-prior-1.0-DA-model-misspecification.pdf (deflated 19%)
#   adding: cold-posterior-images/biglenet-prior-1.0-No-DA-model-misspecification.pdf (deflated 19%)
#   adding: cold-posterior-images/biglenet-prior-1.0-Shuffle-DA-model-misspecification.pdf (deflated 18%)

# %%
files.download("images.zip")
